# %% [markdown]
# # Nordrhein-Westfalen

# %%
# loading libs
import pandas as pd
import Stemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import Stemmer

# %%
# bayern = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/bayern_demojized.csv", index_col=0)
# bawü = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/bawü_demojized.csv", index_col=0)
# berlin = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/berlin_demojized.csv", index_col=0)
# bremen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/bremen_demojized.csv", index_col=0)
# hamburg = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/hamburg_demojized.csv", index_col=0)
# hessen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/hessen_demojized.csv", index_col=0)
# brandenburg = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/brandenburg_demojized.csv", index_col=0)
# mecklenburg = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/meckPomm_demojized.csv", index_col=0)
# niedersachsen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/niedersachsen_demojized.csv", index_col=0)
nrw = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/nrw_demojized.csv", index_col=0)
# rlp = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/rlp_demojized.csv", index_col=0)
# saarland = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/saarland_demojized.csv", index_col=0)
# sachsen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/sachsen_demojized.csv", index_col=0)
# sachsenAnhalt = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/sachsen_anhalt_demojized.csv", index_col=0)
# schleswig = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/schleswig_demojized.csv", index_col=0)
# thüringen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/thüringen_demojized.csv", index_col=0)

# %%
categoriesNrw = {
    'ukraine' : ['ukraine', 'russland', 'krieg', 'putin', 'ukraine-krieg', 'russischen', 'russische',
                 'kiew', 'russlands', 'ukrainische', 'moskau', 'angriff', 'sanktionen',
                 'ukrainekrieg', 'selenskyj'],
    
    'energiekrise' : ['gas', 'preise', 'habeck', 'kosten', 'energiekrise', 'energie', 'teurer', 'strom', 'sparen'],
    
    'wetterKlima' : ['sommer', 'wetter', 'grad', 'wasser', 'hitze'],
    
    'covid' : ['corona', 'inzidenz', 'pandemie', 'lauterbach', 'rki', 'maskenpflicht', 'coronavirus'],
    
    'justiz' : ['polizei', 'täter', 'zeugen', 'verletzte', 'unbekannte', 'stirbt', 'polizei',
                'gericht', 'fall', 'ermittelt', 'prozess', 'urteil', 'haft', 'polizisten',
                'festgenommen', 'ermittlungen', 'opfer', 'landgericht',
                'staatsanwaltschaft', 'verurteilt'],
    
    'flutAhrtal' : ['flut', 'flutkatastrophe', 'ahrtal'],
    
    'politik' : ['cdu', 'spd', 'wüst', 'grüne', 'politik', 'regierung', 'grünen', 'landtagswahl',
                 'fdp', 'debatte', 'wahl', 'bundestag'],
    
    'öpnvVerkehr' : ['bahn', 'flughafen', '9-euro-ticket', 'urlaub', 'fahren', 'mallorca', 'gesperrt',
                     'verkehr', 'autobahn', 'bahnhof', 'sperrung'],
    
    'wirtschaft' : ['euro', 'unternehmen', 'kunden', 'bank', 'markt', 'anleger'],
    
    'unglück' : ['feuerwehr', 'einsatz', 'brand', 'feuer', 'tote', 'flammen', 'großeinsatz']
}

# %%
dfsNrw = []

for key,values in categoriesNrw.items():
    words=pd.DataFrame({'category': key, 'term': values})
    dfsNrw.append(words)

termsNrw = pd.concat(dfsNrw)
termsNrw
# Out:
#    category           term
# 0   ukraine        ukraine
# 1   ukraine       russland
# 2   ukraine          krieg
# 3   ukraine          putin
# 4   ukraine  ukraine-krieg
# ..      ...            ...
# 2   unglück          brand
# 3   unglück          feuer
# 4   unglück           tote
# 5   unglück        flammen
# 6   unglück    großeinsatz
#
# [95 rows x 2 columns]

# %%
# Take the 'term' column from our list of terms
termlistNrw = list(set(termsNrw.term))

# binary=True only does 0/1
# vocabulary= is the list of words we're interested in tracking
vectorizer = TfidfVectorizer(binary=False, vocabulary = termlistNrw)

matrix = vectorizer.fit_transform(nrw.text, )

words_df = pd.DataFrame(matrix.toarray(), columns = vectorizer.get_feature_names_out())

# %%
# Group the terms by category, then loop through each category
for category_name, rows in termsNrw.groupby('category'):
    # Convert the terms for that category into a simple list
    # for example, ['student', 'educ', 'teacher']
    terms = list(rows['term'])
    print(f"Topic: {category_name} \nWorte: {terms} \n")

    # words_df[terms] gets the columns for 'student', 'educ', and 'teacher'
    # .any(axis=1) sees if any of them are a 1, gives True/False
    # .astype(int) converts True/False to 1/0
    # df[category_name] = will assign that value to df['education']
    nrw[category_name] = words_df[terms].any(axis=1).astype(int)
# Out:
# Topic: covid
# Worte: ['corona', 'inzidenz', 'pandemie', 'lauterbach', 'rki', 'maskenpflicht', 'coronavirus']
#
# Topic: energiekrise
# Worte: ['gas', 'preise', 'habeck', 'kosten', 'energiekrise', 'energie', 'teurer', 'strom', 'sparen']
#
# Topic: flutAhrtal
# Worte: ['flut', 'flutkatastrophe', 'ahrtal']
#
# Topic: justiz
# Worte: ['polizei', 'täter', 'zeugen', 'verletzte', 'unbekannte', 'stirbt', 'polizei', 'gericht', 'fall', 'ermittelt', 'prozess', 'urteil', 'haft', 'polizisten', 'festgenommen', 'ermittlungen', 'opfer', 'landgericht', 'staatsanwaltschaft', 'verurteilt']
#
# Topic: politik
# Worte: ['cdu', 'spd', 'wüst', 'grüne', 'politik', 'regierung', 'grünen', 'landtagswahl', 'fdp', 'debatte', 'wahl', 'bundestag']
#
# Topic: ukraine
# Worte: ['ukraine', 'russland', 'krieg', 'putin', 'ukraine-krieg', 'russischen', 'russische', 'kiew', 'russlands', 'ukrainische', 'moskau', 'angriff', 'sanktionen', 'ukrainekrieg', 'selenskyj']
#
# Topic: unglück
# Worte: ['feuerwehr', 'einsatz', 'brand', 'feuer', 'tote', 'flammen', 'großeinsatz']
#
# Topic: wetterKlima
# Worte: ['sommer', 'wetter', 'grad', 'wasser', 'hitze']
#
# Topic: wirtschaft
# Worte: ['euro', 'unternehmen', 'kunden', 'bank', 'markt', 'anleger']
#
# Topic: öpnvVerkehr
# Worte: ['bahn', 'flughafen', '9-euro-ticket', 'urlaub', 'fahren', 'mallorca', 'gesperrt', 'verkehr', 'autobahn', 'bahnhof', 'sperrung']

# %%
nrw.groupby('user').energiekrise.sum().sort_values(ascending=False)
# Out:
# user
# wznewsline         947
# handelsblatt       865
# WAZ_Redaktion      550
# rponline           424
# gabonn             406
# WN_Redaktion       232
# KSTA               215
# nwnews             164
# RN_DORTMUND        147
# WA_online          144
# westfalenblatt     101
# soesteranzeiger     90
# express24           63
# handwerksblatt      59
# MT_Online           46
# DieGlocke           46
# Sauerlandkurier     45
# aachenerzeitung     42
# UnsereZeit_UZ       38
# DZ_Duelmen          33
# blickaktuell        32
# DasSauerland        23
# KoelnischeR         22
# KreisblattHalle     22
# WRundschau          11
# SGTageblatt          3
# rgaonline            2
# UnsereKirche         2
# lzonline             1
# SiegenerZeitung      1
# Name: energiekrise, dtype: int64

# %%
nrw.groupby('user').sum()
# Out:
#                                                           dateTime  \
# user
# DZ_Duelmen       2022-10-31T18:23:04Z2022-10-31T17:27:36Z2022-1...
# DasSauerland     2022-10-30T13:54:36Z2022-10-30T13:54:34Z2022-1...
# DieGlocke        2022-10-31T18:06:39Z2022-10-31T18:06:37Z2022-1...
# KSTA             2022-10-31T19:44:01Z2022-10-31T19:00:43Z2022-1...
# KoelnischeR      2022-10-31T09:44:34Z2022-10-31T06:32:20Z2022-1...
# KreisblattHalle  2022-10-11T09:40:10Z2022-10-11T08:56:12Z2022-1...
# MT_Online        2022-10-31T19:29:35Z2022-10-31T18:04:47Z2022-1...
# RN_DORTMUND      2022-10-31T22:28:55Z2022-10-31T21:43:26Z2022-1...
# SGTageblatt      2022-10-23T14:37:31Z2022-10-18T11:00:02Z2022-0...
# Sauerlandkurier  2022-10-31T20:14:39Z2022-10-31T19:10:26Z2022-1...
# SiegenerZeitung  2022-10-31T22:47:16Z2022-10-31T19:16:35Z2022-1...
# UnsereKirche     2022-10-28T07:18:13Z2022-10-27T07:53:50Z2022-1...
# UnsereZeit_UZ    2022-10-28T11:00:28Z2022-10-28T09:00:25Z2022-1...
# WAZ_Redaktion    2022-10-31T22:01:19Z2022-10-31T21:58:47Z2022-1...
# WA_online        2022-10-31T23:55:12Z2022-10-31T19:39:50Z2022-1...
# WN_Redaktion     2022-10-31T20:00:02Z2022-10-31T19:30:00Z2022-1...
# WRundschau       2022-10-29T20:12:42Z2022-10-29T17:18:34Z2022-1...
# aachenerzeitung  2022-10-31T20:00:12Z2022-10-31T17:14:43Z2022-1...
# blickaktuell     2022-10-31T21:43:49Z2022-10-31T21:43:33Z2022-1...
# express24        2022-10-31T13:05:15Z2022-10-31T11:37:00Z2022-1...
# gabonn           2022-10-31T20:30:35Z2022-10-31T20:11:03Z2022-1...
# handelsblatt     2022-10-31T18:53:00Z2022-10-31T18:22:56Z2022-1...
# handwerksblatt   2022-10-31T17:00:02Z2022-10-31T15:30:00Z2022-1...
# lzonline         2022-10-30T16:18:00Z2022-10-30T13:57:20Z2022-1...
# nwnews           2022-10-31T15:20:01Z2022-10-31T14:20:01Z2022-1...
# rgaonline        2022-10-23T16:31:09Z2022-08-14T10:11:31Z2022-0...
# rponline         2022-10-31T21:00:43Z2022-10-31T20:01:37Z2022-1...
# soesteranzeiger  2022-10-31T23:23:29Z2022-10-31T21:05:00Z2022-1...
# westfalenblatt   2022-10-31T20:00:49Z2022-10-31T18:58:55Z2022-1...
# wznewsline       2022-10-31T23:40:34Z2022-10-31T23:31:36Z2022-1...
#
#                       tweetID  \
# user
# DZ_Duelmen       2.068265e+21
# DasSauerland     7.454687e+20
# DieGlocke        4.748729e+21
# KSTA             8.257418e+21
# KoelnischeR      5.591053e+20
# KreisblattHalle  1.559553e+21
# MT_Online        3.914228e+21
# RN_DORTMUND      8.303019e+21
# SGTageblatt      1.940234e+20
# Sauerlandkurier  5.119678e+21
# SiegenerZeitung  7.449310e+19
# UnsereKirche     2.417340e+20
# UnsereZeit_UZ    9.371721e+20
# WAZ_Redaktion    3.271373e+22
# WA_online        7.556835e+21
# WN_Redaktion     1.121936e+22
# WRundschau       6.331438e+20
# aachenerzeitung  2.082002e+21
# blickaktuell     6.359620e+21
# express24        5.387797e+21
# gabonn           1.705378e+22
# handelsblatt     1.587871e+22
# handwerksblatt   1.617602e+21
# lzonline         2.333869e+20
# nwnews           4.073513e+21
# rgaonline        1.698655e+20
# rponline         1.252181e+22
# soesteranzeiger  7.559437e+21
# westfalenblatt   6.271317e+21
# wznewsline       8.895505e+22
#
#                                                            content  replies  \
# user
# DZ_Duelmen       Sirene im richtigen Moment: Obwohl GW Hausdülm...       44
# DasSauerland     Polizeieinsatz: Dortmund: Schussabgaben als „E...       33
# DieGlocke        Oberbürgermeister: „Gutes Pflaster für Diploma...       86
# KSTA             #Putin will Europas Gesellschaften zersetzen, ...     7090
# KoelnischeR      Anonymer Anrufer droht mit Straftat - Schulzen...       86
# KreisblattHalle  New #OpenMicStory Unsichtbaren Geistern auf de...        7
# MT_Online        Wie sich zwei Frauen nicht entmutigen lassen [...      254
# RN_DORTMUND      RN+ Stadt rechnet mit Ansturm bei Wohngeld-Ant...     2977
# SGTageblatt      @wagenbrn \nKorrekt, aber darum ging´s doch ga...       13
# Sauerlandkurier  Allerheiligenmarkt Niederense ist trotz Kritik...       95
# SiegenerZeitung  Bad Laasphe: Die Banfetalschule hat ein Platzp...        1
# UnsereKirche     Ein spannendes und so wichtiges Thema!Nachhilf...       24
# UnsereZeit_UZ    Die Tarifeinigung in der Chemie- und Pharmaind...      535
# WAZ_Redaktion    Halloween-Parade Essen: Das sind Bilder des Zo...     6147
# WA_online        Feiertag steht bevor: andere Zeiten für Müllab...      135
# WN_Redaktion     Das Treffen der #G7-Außenminister in #Münster ...     1329
# WRundschau       Handball-Bundesliga, Endstand: Füchse Berlin –...      104
# aachenerzeitung  Maßnahmen nach Rennen im Ludwig-Erhardt-Ring, ...      360
# blickaktuell     Die Täter schlugen auf einem Rastplatz zu.\n\n...       77
# express24        Nicht nur in sportlicher Hinsicht ist das letz...     1042
# gabonn           Das iranische Regime will härter gegen Protest...     6331
# handelsblatt     Seit der Mobilmachung haben 700.000 Russen ihr...    34143
# handwerksblatt   #Gaskommission hat ihren #Abschlussbericht vor...       73
# lzonline         Qualitäten als Tierbändiger waren heute bei de...       13
# nwnews           Ein Mann hat im polnischen #Kattowitz eine #St...     2146
# rgaonline        Einfach nur  man_facepalming : Mann fährt ohne...        4
# rponline         Nirgendwo in #NRW sind die Mensapreise so star...    15682
# soesteranzeiger  36. Allerheiligenmarkt in Niederense https://t...       86
# westfalenblatt   Hörmann verzichtet auf Grundstück im Steinhage...     1327
# wznewsline       Verwaltungsrat aufgelöst: Musk alleiniger Twit...     2412
#
#                  retweets  likes  quotes  \
# user
# DZ_Duelmen             45    165      22
# DasSauerland           44    157       8
# DieGlocke              70    821      48
# KSTA                 4809  20192    1787
# KoelnischeR            62    156      17
# KreisblattHalle        10    139       2
# MT_Online             213    435     106
# RN_DORTMUND          7185   7000    1176
# SGTageblatt            12     55       2
# Sauerlandkurier        75    607      37
# SiegenerZeitung         1     13       0
# UnsereKirche           54    316      16
# UnsereZeit_UZ        2145   4680     212
# WAZ_Redaktion        3483  15300    1616
# WA_online             136    446      23
# WN_Redaktion         3060  11132     930
# WRundschau            344   1042      61
# aachenerzeitung       211    576      92
# blickaktuell          442   1148      52
# express24             576   2324     262
# gabonn               3068  18488    1282
# handelsblatt        31750  92215    7224
# handwerksblatt        428   2512      54
# lzonline               46    187      10
# nwnews               1789   7560     833
# rgaonline               9     35       1
# rponline             6272  26377    2691
# soesteranzeiger        53    310      22
# westfalenblatt       1243   3904     419
# wznewsline           3010   5461     537
#
#                                                              media  \
# user
# DZ_Duelmen       [Photo(previewUrl='https://pbs.twimg.com/media...
# DasSauerland     [Photo(previewUrl='https://pbs.twimg.com/media...
# DieGlocke        [Photo(previewUrl='https://pbs.twimg.com/media...
# KSTA             [Photo(previewUrl='https://pbs.twimg.com/media...
# KoelnischeR      [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# KreisblattHalle                                                  0
# MT_Online        [Photo(previewUrl='https://pbs.twimg.com/media...
# RN_DORTMUND      [Photo(previewUrl='https://pbs.twimg.com/media...
# SGTageblatt      [Photo(previewUrl='https://pbs.twimg.com/media...
# Sauerlandkurier  [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# SiegenerZeitung  [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# UnsereKirche     [Photo(previewUrl='https://pbs.twimg.com/media...
# UnsereZeit_UZ    [Photo(previewUrl='https://pbs.twimg.com/media...
# WAZ_Redaktion    [Photo(previewUrl='https://pbs.twimg.com/media...
# WA_online        [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# WN_Redaktion     [Photo(previewUrl='https://pbs.twimg.com/media...
# WRundschau       [Photo(previewUrl='https://pbs.twimg.com/media...
# aachenerzeitung  [Photo(previewUrl='https://pbs.twimg.com/media...
# blickaktuell     [Photo(previewUrl='https://pbs.twimg.com/media...
# express24        [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# gabonn           [Photo(previewUrl='https://pbs.twimg.com/media...
# handelsblatt     [Photo(previewUrl='https://pbs.twimg.com/media...
# handwerksblatt   [Photo(previewUrl='https://pbs.twimg.com/media...
# lzonline         [Photo(previewUrl='https://pbs.twimg.com/media...
# nwnews           [Photo(previewUrl='https://pbs.twimg.com/media...
# rgaonline        [Photo(previewUrl='https://pbs.twimg.com/media...
# rponline         [Photo(previewUrl='https://pbs.twimg.com/media...
# soesteranzeiger  [Photo(previewUrl='https://pbs.twimg.com/media...
# westfalenblatt   [Photo(previewUrl='https://pbs.twimg.com/media...
# wznewsline       [Photo(previewUrl='https://pbs.twimg.com/media...
#
#                  isRetweeted  isQuoted  ...  covid energiekrise flutAhrtal  \
# user                                    ...
# DZ_Duelmen               0.0       0.0  ...    140           33          2
# DasSauerland             0.0       0.0  ...     41           23          3
# DieGlocke                0.0       0.0  ...     73           46          4
# KSTA                     0.0       0.0  ...    388          215         31
# KoelnischeR              0.0       0.0  ...     12           22          0
# KreisblattHalle          0.0       0.0  ...     45           22          0
# MT_Online                0.0       0.0  ...    102           46          1
# RN_DORTMUND              0.0       0.0  ...    532          147          2
# SGTageblatt              0.0       0.0  ...      9            3          0
# Sauerlandkurier          0.0       0.0  ...    213           45          4
# SiegenerZeitung          0.0       0.0  ...      0            1          0
# UnsereKirche             0.0       0.0  ...      3            2          1
# UnsereZeit_UZ            0.0       0.0  ...     15           38          0
# WAZ_Redaktion            0.0       0.0  ...    931          550         17
# WA_online                0.0       0.0  ...    308          144          2
# WN_Redaktion             0.0       0.0  ...    954          232         15
# WRundschau               0.0       0.0  ...     13           11          0
# aachenerzeitung          0.0       0.0  ...     39           42         10
# blickaktuell             0.0       0.0  ...     52           32        277
# express24                0.0       0.0  ...    215           63          1
# gabonn                   0.0       0.0  ...    850          406        409
# handelsblatt             0.0       0.0  ...    307          865          6
# handwerksblatt           0.0       0.0  ...     90           59          6
# lzonline                 0.0       0.0  ...      4            1          0
# nwnews                   0.0       0.0  ...    228          164          7
# rgaonline                0.0       0.0  ...     19            2          0
# rponline                 0.0       0.0  ...    613          424         40
# soesteranzeiger          0.0       0.0  ...    183           90          5
# westfalenblatt           0.0       0.0  ...    491          101          6
# wznewsline               0.0       0.0  ...   3036          947         93
#
#                  justiz  politik ukraine  unglück  wetterKlima wirtschaft  \
# user
# DZ_Duelmen          102       31      39       49           41         50
# DasSauerland         88       23      25       38           14         26
# DieGlocke           218       57      44       74           24         54
# KSTA                517      357     424      128           76        177
# KoelnischeR          31       14      36       17           14          6
# KreisblattHalle      74        8      17       31            9         31
# MT_Online           178       39      29       71           18         44
# RN_DORTMUND         449      106     152      162           59        142
# SGTageblatt           7        8       2        4            0          6
# Sauerlandkurier     202       51      90      168           17         49
# SiegenerZeitung       1        0       0        5            0          1
# UnsereKirche          1        0       8        0            5          3
# UnsereZeit_UZ        15       48     173        5            5         26
# WAZ_Redaktion       945      407    1200      403          147        388
# WA_online           308      114      92      143           43        113
# WN_Redaktion        682      293     560      218          141        225
# WRundschau           73       25      19       62           19         11
# aachenerzeitung     142       48      28       34           13         39
# blickaktuell        642       28      30      215           27         73
# express24           488       46      87      133          123         89
# gabonn             1190      619     981      415          261        445
# handelsblatt        214      735    1924       39           55       1435
# handwerksblatt      101       54      34        3            6        135
# lzonline             22        2       3       22            1          4
# nwnews              215      120     241       63           87        152
# rgaonline             8        5       4        3            0          5
# rponline            579      748    1216      158          118        298
# soesteranzeiger     271       78     106      248           34        119
# westfalenblatt      642      239     219      236           99        167
# wznewsline         3002     1565    2895     1137          448        894
#
#                  öpnvVerkehr
# user
# DZ_Duelmen                57
# DasSauerland              35
# DieGlocke                 68
# KSTA                     239
# KoelnischeR               21
# KreisblattHalle           26
# MT_Online                 48
# RN_DORTMUND              221
# SGTageblatt                8
# Sauerlandkurier           58
# SiegenerZeitung            3
# UnsereKirche               2
# UnsereZeit_UZ              8
# WAZ_Redaktion            454
# WA_online                150
# WN_Redaktion             217
# WRundschau                30
# aachenerzeitung           42
# blickaktuell             121
# express24                221
# gabonn                   524
# handelsblatt              94
# handwerksblatt            11
# lzonline                   9
# nwnews                   159
# rgaonline                  7
# rponline                 222
# soesteranzeiger           92
# westfalenblatt           168
# wznewsline               888
#
# [30 rows x 37 columns]

# %%
nrwCategorized = nrw
nrwCategorized.to_csv("../../methods/representative-speech/mediendaten/zuordnungenBundesländer/nrwCategorized.csv")
