# %% [markdown]
# # Rheinland-Pfalz

# %%
# loading libs
import pandas as pd
import Stemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import Stemmer

# %%
# bayern = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/bayern_demojized.csv", index_col=0)
# bawü = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/bawü_demojized.csv", index_col=0)
# berlin = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/berlin_demojized.csv", index_col=0)
# bremen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/bremen_demojized.csv", index_col=0)
# hamburg = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/hamburg_demojized.csv", index_col=0)
# hessen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/hessen_demojized.csv", index_col=0)
# brandenburg = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/brandenburg_demojized.csv", index_col=0)
# mecklenburg = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/meckPomm_demojized.csv", index_col=0)
# niedersachsen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/niedersachsen_demojized.csv", index_col=0)
# nrw = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/nrw_demojized.csv", index_col=0)
rlp = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/rlp_demojized.csv", index_col=0)
# saarland = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/saarland_demojized.csv", index_col=0)
# sachsen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/sachsen_demojized.csv", index_col=0)
# sachsenAnhalt = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/sachsen_anhalt_demojized.csv", index_col=0)
# schleswig = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/schleswig_demojized.csv", index_col=0)
# thüringen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/thüringen_demojized.csv", index_col=0)

# %%
categoriesRlp = {    
    'energiekrise' : ['preise', 'kunden', 'gas', 'kosten', 'teurer', 'energiekrise', 'sparen', 'strom',
                      'energie', 'verbraucher', 'spritpreise'],
    
    'ukraine' : ['ukraine', 'russland', 'krieg', 'putin', 'russischen', 'russische', 'ukrainische', 'ukraine-krieg',
                 'ukrainischen', 'geflüchtete', 'russlands', 'angriff', 'kiew', 'moskau'],
    
    'unglück' : ['verletzt', 'unfall', 'gesperrt', 'verkehrsunfall', 'feuerwehr', 'einsatz', 'brand', 'feuer'],
    
    'politik' : ['cdu', 'spd', 'oberbürgermeister', 'amt', 'wahl', 'gewählt', 'bürgermeister', 'grünen', 'kandidaten'],
    
    'covid' : ['corona', 'coronavirus', 'lauterbach', 'maskenpflicht', 'corona-regeln', 'impfung', 'corona-maßnahmen',
               'inzidenz', 'neuinfektionen', 'pandemie', 'omikron'],
    
    'flutAhrtal' : ['ahrtal', 'birkenfeld', 'flutkatastrophe', 'flut', 'ahrweiler', 'ahr'],
    
    'polizistenmordKusel' : ['kusel']
}

# %%
dfsRlp = []

for key,values in categoriesRlp.items():
    words=pd.DataFrame({'category': key, 'term': values})
    dfsRlp.append(words)

termsRlp = pd.concat(dfsRlp)
termsRlp
# Out:
#                category               term
# 0          energiekrise             preise
# 1          energiekrise             kunden
# 2          energiekrise                gas
# 3          energiekrise             kosten
# 4          energiekrise             teurer
# 5          energiekrise       energiekrise
# 6          energiekrise             sparen
# 7          energiekrise              strom
# 8          energiekrise            energie
# 9          energiekrise        verbraucher
# 10         energiekrise        spritpreise
# 0               ukraine            ukraine
# 1               ukraine           russland
# 2               ukraine              krieg
# 3               ukraine              putin
# 4               ukraine         russischen
# 5               ukraine          russische
# 6               ukraine        ukrainische
# 7               ukraine      ukraine-krieg
# 8               ukraine       ukrainischen
# 9               ukraine        geflüchtete
# 10              ukraine          russlands
# 11              ukraine            angriff
# 12              ukraine               kiew
# 13              ukraine             moskau
# 0               unglück           verletzt
# 1               unglück             unfall
# 2               unglück           gesperrt
# 3               unglück     verkehrsunfall
# 4               unglück          feuerwehr
# 5               unglück            einsatz
# 6               unglück              brand
# 7               unglück              feuer
# 0               politik                cdu
# 1               politik                spd
# 2               politik  oberbürgermeister
# 3               politik                amt
# 4               politik               wahl
# 5               politik            gewählt
# 6               politik      bürgermeister
# 7               politik             grünen
# 8               politik         kandidaten
# 0                 covid             corona
# 1                 covid        coronavirus
# 2                 covid         lauterbach
# 3                 covid      maskenpflicht
# 4                 covid      corona-regeln
# 5                 covid            impfung
# 6                 covid   corona-maßnahmen
# 7                 covid           inzidenz
# 8                 covid     neuinfektionen
# 9                 covid           pandemie
# 10                covid            omikron
# 0            flutAhrtal             ahrtal
# 1            flutAhrtal         birkenfeld
# 2            flutAhrtal    flutkatastrophe
# 3            flutAhrtal               flut
# 4            flutAhrtal          ahrweiler
# 5            flutAhrtal                ahr
# 0   polizistenmordKusel              kusel

# %%
# Take the 'term' column from our list of terms
termlistRlp = list(set(termsRlp.term))

# binary=True only does 0/1
# vocabulary= is the list of words we're interested in tracking
vectorizer = TfidfVectorizer(binary=False, vocabulary = termlistRlp)

matrix = vectorizer.fit_transform(rlp.text, )

words_df = pd.DataFrame(matrix.toarray(), columns = vectorizer.get_feature_names_out())

# %%
# Group the terms by category, then loop through each category
for category_name, rows in termsRlp.groupby('category'):
    # Convert the terms for that category into a simple list
    # for example, ['student', 'educ', 'teacher']
    terms = list(rows['term'])
    print(f"Topic: {category_name} \nWorte: {terms} \n")

    # words_df[terms]  -> die einzelnen bestandteile der categories (also die wörter der topics)
    # .any(axis=1) -> prüfen, ob irgendeines von den wörtern != 0
    # .astype(int) macht aus True bzw. False einen binären atomic vector
    # df[category_name] -> wird dann zu dem jeweiligen df als variable "category_name" zugewiesen
    rlp[category_name] = words_df[terms].any(axis=1).astype(int)
# Out:
# Topic: covid
# Worte: ['corona', 'coronavirus', 'lauterbach', 'maskenpflicht', 'corona-regeln', 'impfung', 'corona-maßnahmen', 'inzidenz', 'neuinfektionen', 'pandemie', 'omikron']
#
# Topic: energiekrise
# Worte: ['preise', 'kunden', 'gas', 'kosten', 'teurer', 'energiekrise', 'sparen', 'strom', 'energie', 'verbraucher', 'spritpreise']
#
# Topic: flutAhrtal
# Worte: ['ahrtal', 'birkenfeld', 'flutkatastrophe', 'flut', 'ahrweiler', 'ahr']
#
# Topic: politik
# Worte: ['cdu', 'spd', 'oberbürgermeister', 'amt', 'wahl', 'gewählt', 'bürgermeister', 'grünen', 'kandidaten']
#
# Topic: polizistenmordKusel
# Worte: ['kusel']
#
# Topic: ukraine
# Worte: ['ukraine', 'russland', 'krieg', 'putin', 'russischen', 'russische', 'ukrainische', 'ukraine-krieg', 'ukrainischen', 'geflüchtete', 'russlands', 'angriff', 'kiew', 'moskau']
#
# Topic: unglück
# Worte: ['verletzt', 'unfall', 'gesperrt', 'verkehrsunfall', 'feuerwehr', 'einsatz', 'brand', 'feuer']

# %%
rlp.groupby('user').polizistenmordKusel.sum().sort_values(ascending=False)
# Out:
# user
# aznachrichten    28
# wznachrichten    24
# RheinZeitung     20
# rheinpfalz       17
# Volksfreund      15
# Name: polizistenmordKusel, dtype: int64

# %%
rlp.groupby('user').sum()
# Out:
#                                                         dateTime  \
# user
# RheinZeitung   2022-10-31T18:57:25Z2022-10-31T15:57:10Z2022-1...
# Volksfreund    2022-10-31T21:00:03Z2022-10-31T20:00:03Z2022-1...
# aznachrichten  2022-10-31T21:29:13Z2022-10-31T20:38:42Z2022-1...
# rheinpfalz     2022-10-15T16:37:47Z2022-10-15T13:27:42Z2022-1...
# wznachrichten  2022-10-31T16:41:02Z2022-10-31T16:19:07Z2022-1...
#
#                     tweetID  \
# user
# RheinZeitung   4.172560e+21
# Volksfreund    5.378282e+21
# aznachrichten  1.047963e+22
# rheinpfalz     1.207096e+21
# wznachrichten  5.161675e+21
#
#                                                          content  replies  \
# user
# RheinZeitung   Ein 30-Tonnen-Schiff auf dem Weg nach Belgien ...      862
# Volksfreund    Der letzte große deutsche Warenhauskonzern käm...      341
# aznachrichten  Unser Text zur Mitgliederversammlung von Mainz...      867
# rheinpfalz     CDU-Chef Baldauf im Interview mit der RHEINPFA...      260
# wznachrichten  Die Besuchermassen im Wormser Tiergarten haben...      117
#
#                retweets  likes  quotes  \
# user
# RheinZeitung        942   2156     101
# Volksfreund         338   1340      92
# aznachrichten      1232   3973     443
# rheinpfalz          463   1753     141
# wznachrichten       141    503      27
#
#                                                            media  isRetweeted  \
# user
# RheinZeitung   [Photo(previewUrl='https://pbs.twimg.com/media...          0.0
# Volksfreund    [Photo(previewUrl='https://pbs.twimg.com/media...          0.0
# aznachrichten  [Video(thumbnailUrl='https://pbs.twimg.com/ext...          0.0
# rheinpfalz     [Photo(previewUrl='https://pbs.twimg.com/media...          0.0
# wznachrichten  [Photo(previewUrl='https://pbs.twimg.com/media...          0.0
#
#                isQuoted  ...  normenWerte geschäftsmodell  \
# user                     ...
# RheinZeitung        0.0  ...         2725            5450
# Volksfreund         0.0  ...         3513            7026
# aznachrichten       0.0  ...         6834           13668
# rheinpfalz          0.0  ...          798            1596
# wznachrichten       0.0  ...         3375            6750
#
#                                                             text  covid  \
# user
# RheinZeitung   ein 30-tonnen-schiff auf dem weg nach belgien ...    296
# Volksfreund    der letzte große deutsche warenhauskonzern käm...    218
# aznachrichten  unser text zur mitgliederversammlung von mainz...    557
# rheinpfalz     cdu-chef baldauf im interview mit der rheinpfa...    124
# wznachrichten  die besuchermassen im wormser tiergarten haben...    391
#
#                energiekrise flutAhrtal  politik  ukraine unglück  \
# user
# RheinZeitung             63        316       91       88     213
# Volksfreund             228         55       98      139     225
# aznachrichten           303         98      299      454     371
# rheinpfalz               13         17       22       27      42
# wznachrichten           162         70      115      316     166
#
#                polizistenmordKusel
# user
# RheinZeitung                    20
# Volksfreund                     15
# aznachrichten                   28
# rheinpfalz                      17
# wznachrichten                   24
#
# [5 rows x 34 columns]

# %%
rlpCategorized = rlp
rlpCategorized.to_csv("../../methods/representative-speech/mediendaten/zuordnungenBundesländer/rlpCategorized.csv")
