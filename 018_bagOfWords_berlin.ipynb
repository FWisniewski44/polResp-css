# %% [markdown]
# # Berlin

# %%
# loading libs
import pandas as pd
import Stemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import Stemmer

# %%
# bayern = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/bayern_demojized.csv", index_col=0)
# bawü = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/bawü_demojized.csv", index_col=0)
berlin = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/berlin_demojized.csv", index_col=0)
# bremen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/bremen_demojized.csv", index_col=0)
# hamburg = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/hamburg_demojized.csv", index_col=0)
# hessen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/hessen_demojized.csv", index_col=0)
# brandenburg = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/brandenburg_demojized.csv", index_col=0)
# mecklenburg = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/meckPomm_demojized.csv", index_col=0)
# niedersachsen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/niedersachsen_demojized.csv", index_col=0)
# nrw = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/nrw_demojized.csv", index_col=0)
# rlp = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/rlp_demojized.csv", index_col=0)
# saarland = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/saarland_demojized.csv", index_col=0)
# sachsen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/sachsen_demojized.csv", index_col=0)
# sachsenAnhalt = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/sachsen_anhalt_demojized.csv", index_col=0)
# schleswig = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/schleswig_demojized.csv", index_col=0)
# thüringen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/thüringen_demojized.csv", index_col=0)

# %%
categoriesBerlin = {
    'energiekrise' : ['gas', 'habeck', 'preise', 'energiekrise', 'energie', 'kosten', 'sparen'],
    
    'protestaktionen' : ['frauen', 'leben', 'kampf', 'iran', 'gewalt', 'angst', 'sorgen', 'proteste'],
    
    'sozialpolitik' : ['kinder', 'geld', 'hilfe', 'arbeit', 'helfen', 'geflüchtete', 'flüchtlinge',
                       'unterstützung', 'eltern', 'arbeiten', 'schule', 'kindern'],
    
    'unglücke' : ['einsatz', 'feuerwehr', 'feuer', 'brand', 'tote', 'gesperrt'],
    
    'politik' : ['scholz', 'bundesregierung', 'bundestag', 'impfpflicht', 'kanzler',
                 'bundeskanzler', 'debatte', 'bundeswehr', 'ampel', 'rede', 'merz',
                 'spd', 'linke', 'cdu', 'afd', 'partei', 'grünen', 'fdp',
                 'grüne', 'wahl', 'ministerpräsident', 'amt', 'lindner',
                 'linken', 'parlament', 'macron'],
    
    'antisemitismusdebatte' : ['jüdische', 'jüdischen', 'juden', 'antisemitismus', 'documenta', 'rassismus'],
    
    'öpnv' : ['bahn', 'bvg', '9euroticket', 'bahnhof', 'fahren'],
    
    'ukraine' : ['ukraine', 'russland', 'krieg', 'putin', 'russischen', 'russische',
                 'ukrainische', 'ukrainekrieg', 'kiew', 'ukrainischen', 'selenskyj',
                 'russlands', 'angriff', 'moskau', 'putins', 'truppen', 'sanktionen', 'waffen'],
    
    'justiz' : ['gericht', 'polizei', 'prozess', 'fall', 'getötet', 'verurteilt', 'haft',
                'festgenommen', 'staatsanwaltschaft', 'ermittlungen', 'vorwürfe', 'urteil',
                'polizisten', 'richter', 'verfahren'],
    
    'lokalesBerlin' : ['berliner', 'berlin', 'berlins', 'senat', 'giffey', 'bürgermeisterin',
                'bezirke', 'abgeordnetenhaus', 'friedrichstraße', 'brandenburger',
                'spandau', 'pankow', 'lichtenberg', 'reinickendorf'],
    
    'covid' : ['corona', 'lauterbach', 'pandemie', 'maskenpflicht', 'omikron',
               'gesundheitsminister', 'coronavirus'],
    
    'unfälle' : ['verletzt', 'unfall', 'verletzte', 'flucht', 'tot', 'krankenhaus']
}

# %%
dfsBerlin = []

for key,values in categoriesBerlin.items():
    words=pd.DataFrame({'category': key, 'term': values})
    dfsBerlin.append(words)

termsBerlin = pd.concat(dfsBerlin)
termsBerlin
# Out:
#         category          term
# 0   energiekrise           gas
# 1   energiekrise        habeck
# 2   energiekrise        preise
# 3   energiekrise  energiekrise
# 4   energiekrise       energie
# ..           ...           ...
# 1        unfälle        unfall
# 2        unfälle     verletzte
# 3        unfälle        flucht
# 4        unfälle           tot
# 5        unfälle   krankenhaus
#
# [130 rows x 2 columns]

# %%
# Take the 'term' column from our list of terms
termlistBerlin = list(set(termsBerlin.term))

# binary=True only does 0/1
# vocabulary= is the list of words we're interested in tracking
vectorizer = TfidfVectorizer(binary=False, vocabulary = termlistBerlin)

matrix = vectorizer.fit_transform(berlin.text, )

words_df = pd.DataFrame(matrix.toarray(), columns = vectorizer.get_feature_names_out())

# %%
# Group the terms by category, then loop through each category
for category_name, rows in termsBerlin.groupby('category'):
    # Convert the terms for that category into a simple list
    # for example, ['student', 'educ', 'teacher']
    terms = list(rows['term'])
    print(f"Looking at {category_name} with terms {terms}")

    # words_df[terms] gets the columns for 'student', 'educ', and 'teacher'
    # .any(axis=1) sees if any of them are a 1, gives True/False
    # .astype(int) converts True/False to 1/0
    # df[category_name] = will assign that value to df['education']
    berlin[category_name] = words_df[terms].any(axis=1).astype(int)
# Out:
# Looking at antisemitismusdebatte with terms ['jüdische', 'jüdischen', 'juden', 'antisemitismus', 'documenta', 'rassismus']
# Looking at covid with terms ['corona', 'lauterbach', 'pandemie', 'maskenpflicht', 'omikron', 'gesundheitsminister', 'coronavirus']
# Looking at energiekrise with terms ['gas', 'habeck', 'preise', 'energiekrise', 'energie', 'kosten', 'sparen']
# Looking at justiz with terms ['gericht', 'polizei', 'prozess', 'fall', 'getötet', 'verurteilt', 'haft', 'festgenommen', 'staatsanwaltschaft', 'ermittlungen', 'vorwürfe', 'urteil', 'polizisten', 'richter', 'verfahren']
# Looking at lokalesBerlin with terms ['berliner', 'berlin', 'berlins', 'senat', 'giffey', 'bürgermeisterin', 'bezirke', 'abgeordnetenhaus', 'friedrichstraße', 'brandenburger', 'spandau', 'pankow', 'lichtenberg', 'reinickendorf']
# Looking at politik with terms ['scholz', 'bundesregierung', 'bundestag', 'impfpflicht', 'kanzler', 'bundeskanzler', 'debatte', 'bundeswehr', 'ampel', 'rede', 'merz', 'spd', 'linke', 'cdu', 'afd', 'partei', 'grünen', 'fdp', 'grüne', 'wahl', 'ministerpräsident', 'amt', 'lindner', 'linken', 'parlament', 'macron']
# Looking at protestaktionen with terms ['frauen', 'leben', 'kampf', 'iran', 'gewalt', 'angst', 'sorgen', 'proteste']
# Looking at sozialpolitik with terms ['kinder', 'geld', 'hilfe', 'arbeit', 'helfen', 'geflüchtete', 'flüchtlinge', 'unterstützung', 'eltern', 'arbeiten', 'schule', 'kindern']
# Looking at ukraine with terms ['ukraine', 'russland', 'krieg', 'putin', 'russischen', 'russische', 'ukrainische', 'ukrainekrieg', 'kiew', 'ukrainischen', 'selenskyj', 'russlands', 'angriff', 'moskau', 'putins', 'truppen', 'sanktionen', 'waffen']
# Looking at unfälle with terms ['verletzt', 'unfall', 'verletzte', 'flucht', 'tot', 'krankenhaus']
# Looking at unglücke with terms ['einsatz', 'feuerwehr', 'feuer', 'brand', 'tote', 'gesperrt']
# Looking at öpnv with terms ['bahn', 'bvg', '9euroticket', 'bahnhof', 'fahren']

# %%
berlin.groupby('user').politik.sum().sort_values(ascending=False)
# Out:
# user
# Tagesspiegel       2630
# berlinerzeitung    1835
# ndaktuell          1281
# Junge_Freiheit      999
# vorwaerts           659
# morgenpost          570
# bzberlin            532
# BERLINER_KURIER     459
# JuedischeOnline     313
# berlinerwoche       224
# TspCheckpoint       180
# Jungle_World        106
# BerlAbendblatt       15
# tag_des_herrn         6
# pukzeitung            4
# Name: politik, dtype: int64

# %%
berlin.groupby('user').sum()
# Out:
#                                                           dateTime  \
# user
# BERLINER_KURIER  2022-10-31T22:38:57Z2022-10-31T22:17:27Z2022-1...
# BerlAbendblatt   2022-10-31T15:52:37Z2022-10-31T14:38:04Z2022-1...
# JuedischeOnline  2022-10-31T16:59:33Z2022-10-31T15:46:26Z2022-1...
# Junge_Freiheit   2022-10-31T17:49:52Z2022-10-31T17:05:56Z2022-1...
# Jungle_World     2022-10-31T08:08:21Z2022-10-30T14:30:39Z2022-1...
# Tagesspiegel     2022-10-31T22:20:37Z2022-10-31T21:26:41Z2022-1...
# TspCheckpoint    2022-10-31T10:04:50Z2022-10-31T09:39:29Z2022-1...
# berlinerwoche    2022-10-31T23:01:30Z2022-10-31T22:42:23Z2022-1...
# berlinerzeitung  2022-10-31T22:55:53Z2022-10-31T22:41:14Z2022-1...
# bzberlin         2022-10-31T21:53:16Z2022-10-31T21:32:31Z2022-1...
# morgenpost       2022-10-31T22:30:04Z2022-10-31T22:09:06Z2022-1...
# ndaktuell        2022-10-31T17:45:25Z2022-10-31T17:16:51Z2022-1...
# pukzeitung       2022-10-28T10:55:18Z2022-09-21T12:37:00Z2022-0...
# tag_des_herrn    2022-10-28T06:11:26Z2022-10-28T06:11:24Z2022-1...
# vorwaerts        2022-10-31T15:15:41Z2022-10-31T09:38:18Z2022-1...
#
#                       tweetID  \
# user
# BERLINER_KURIER  1.752262e+22
# BerlAbendblatt   6.904215e+20
# JuedischeOnline  5.260342e+21
# Junge_Freiheit   4.318172e+21
# Jungle_World     7.101595e+20
# Tagesspiegel     2.856520e+22
# TspCheckpoint    1.641941e+21
# berlinerwoche    1.325534e+22
# berlinerzeitung  2.649360e+22
# bzberlin         2.772390e+22
# morgenpost       2.010489e+22
# ndaktuell        8.872613e+21
# pukzeitung       2.712881e+20
# tag_des_herrn    9.032375e+20
# vorwaerts        3.561085e+21
#
#                                                            content  replies  \
# user
# BERLINER_KURIER  Unsere Kolumnistin hat diesen dahingeschrieben...     4017
# BerlAbendblatt   Der Oktober war warm... zu warm? Sonne und mil...       50
# JuedischeOnline  Nach einem Gespräch mit dem Kölner Polizeipräs...     7652
# Junge_Freiheit   Der Verfassungsschutz betreibt Hunderte rechts...    39100
# Jungle_World     Der Pragmatismus ihres Führungspersonals könnt...      297
# Tagesspiegel     Für seinen Rassismus gegen Araber wurde er ger...   116599
# TspCheckpoint    Ausgabe von #Urkunden momentan nicht möglich: ...     2766
# berlinerwoche    Übergriffe in Schwimmbädern: Grüne und SPD wol...      269
# berlinerzeitung  In dem Werk des Apple-Zulieferers Foxconn arbe...   200641
# bzberlin         Martin Luther King beglich 1967 Julia Roberts‘...    50447
# morgenpost       Füchse-Manager über Lindberg: „Zukunftsorienti...    18709
# ndaktuell        Der Flügelstreit bei @dieLinke spitzt sich zu....     5967
# pukzeitung       Frisch aus der Druckerei: unsere Novemberausga...       38
# tag_des_herrn    Weltsynode nähert sich der zweiten Phase - htt...       18
# vorwaerts        Die gesetzliche #Krankenversicherung braucht e...     4455
#
#                  retweets   likes  quotes  \
# user
# BERLINER_KURIER      5696   11306     698
# BerlAbendblatt        128     268      29
# JuedischeOnline     30880  126633    3231
# Junge_Freiheit      89350  301591    7992
# Jungle_World         2612    7513     324
# Tagesspiegel       106743  333712   30342
# TspCheckpoint        5907   12524     948
# berlinerwoche        1040    2046     191
# berlinerzeitung    161206  490220   33723
# bzberlin            20735   81369    4945
# morgenpost          11027   28772    2891
# ndaktuell           18417   52461    2851
# pukzeitung            561    1258      18
# tag_des_herrn          11      95      11
# vorwaerts            9181   39811     975
#
#                                                              media  \
# user
# BERLINER_KURIER  [Photo(previewUrl='https://pbs.twimg.com/media...
# BerlAbendblatt   [Photo(previewUrl='https://pbs.twimg.com/media...
# JuedischeOnline  [Photo(previewUrl='https://pbs.twimg.com/media...
# Junge_Freiheit   [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# Jungle_World     [Photo(previewUrl='https://pbs.twimg.com/media...
# Tagesspiegel     [Photo(previewUrl='https://pbs.twimg.com/media...
# TspCheckpoint    [Photo(previewUrl='https://pbs.twimg.com/media...
# berlinerwoche    [Photo(previewUrl='https://pbs.twimg.com/media...
# berlinerzeitung  [Photo(previewUrl='https://pbs.twimg.com/media...
# bzberlin                                                         0
# morgenpost       [Photo(previewUrl='https://pbs.twimg.com/media...
# ndaktuell        [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# pukzeitung       [Photo(previewUrl='https://pbs.twimg.com/media...
# tag_des_herrn    [Photo(previewUrl='https://pbs.twimg.com/media...
# vorwaerts        [Photo(previewUrl='https://pbs.twimg.com/media...
#
#                  isRetweeted  isQuoted  ...  energiekrise justiz  \
# user                                    ...
# BERLINER_KURIER          0.0       0.0  ...           265    675
# BerlAbendblatt           0.0       0.0  ...            15      8
# JuedischeOnline          0.0       0.0  ...            25    237
# Junge_Freiheit           0.0       0.0  ...           141    229
# Jungle_World             0.0       0.0  ...            12     21
# Tagesspiegel             0.0       0.0  ...           636   1566
# TspCheckpoint            0.0       0.0  ...            45     55
# berlinerwoche            0.0       0.0  ...            47     50
# berlinerzeitung          0.0       0.0  ...           728   1086
# bzberlin                 0.0       0.0  ...           230    854
# morgenpost               0.0       0.0  ...           157   1051
# ndaktuell                0.0       0.0  ...           168    297
# pukzeitung               0.0       0.0  ...             1      2
# tag_des_herrn            0.0       0.0  ...             3      3
# vorwaerts                0.0       0.0  ...            53     32
#
#                 lokalesBerlin  politik  protestaktionen sozialpolitik  \
# user
# BERLINER_KURIER          1062      459              348           395
# BerlAbendblatt            158       15               23            13
# JuedischeOnline           246      313              216           175
# Junge_Freiheit            163      999              183           136
# Jungle_World               12      106               47            29
# Tagesspiegel             5725     2630              756          1144
# TspCheckpoint             892      180               26            88
# berlinerwoche             618      224              164           481
# berlinerzeitung          3368     1835              649           875
# bzberlin                 3217      532              317           460
# morgenpost               3904      570              170           459
# ndaktuell                 746     1281              475           424
# pukzeitung                  5        4                6            11
# tag_des_herrn               3        6               14            14
# vorwaerts                  48      659              103           101
#
#                  ukraine  unfälle unglücke  öpnv
# user
# BERLINER_KURIER      832      275      201   131
# BerlAbendblatt         8        9       26    22
# JuedischeOnline      442       37       15     7
# Junge_Freiheit       430       22       23    18
# Jungle_World         117        2        2     0
# Tagesspiegel        4064      568      518   353
# TspCheckpoint        123       19       26    44
# berlinerwoche        147       42       66   105
# berlinerzeitung     2937      379      326   381
# bzberlin             958      561      313   248
# morgenpost           419      585      404   297
# ndaktuell            933       48       45    60
# pukzeitung            25        0        1     0
# tag_des_herrn          8        2        0     0
# vorwaerts            278       16        8    44
#
# [15 rows x 39 columns]

# %%
berlinCategorized = berlin
berlinCategorized.to_csv("../../methods/representative-speech/mediendaten/zuordnungenBundesländer/berlinCategorized.csv")
