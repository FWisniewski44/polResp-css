# %% [markdown]
# # Niedersachsen

# %%
# loading libs
import pandas as pd
import numpy as np
import pprint as pp
import Stemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import Stemmer

# %%
# bayern = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/bayern_demojized.csv", index_col=0)
# bawü = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/bawü_demojized.csv", index_col=0)
# berlin = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/berlin_demojized.csv", index_col=0)
# bremen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/bremen_demojized.csv", index_col=0)
# hamburg = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/hamburg_demojized.csv", index_col=0)
# hessen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/hessen_demojized.csv", index_col=0)
# brandenburg = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/brandenburg_demojized.csv", index_col=0)
# mecklenburg = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/meckPomm_demojized.csv", index_col=0)
niedersachsen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/niedersachsen_demojized.csv", index_col=0)
# nrw = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/nrw_demojized.csv", index_col=0)
# rlp = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/rlp_demojized.csv", index_col=0)
# saarland = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/saarland_demojized.csv", index_col=0)
# sachsen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/sachsen_demojized.csv", index_col=0)
# sachsenAnhalt = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/sachsen_anhalt_demojized.csv", index_col=0)
# schleswig = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/schleswig_demojized.csv", index_col=0)
# thüringen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/thüringen_demojized.csv", index_col=0)
# Out:
# /tmp/ipykernel_29596/2252671018.py:9: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   niedersachsen = pd.read_csv("../../methods/representative-speech/regionalisierung/demojized/niedersachsen_demojized.csv", index_col=0)

# %%
categoriesNiedersachsen = {
    'energiekrise' : ['gas', 'energiekrise', 'energie', 'teurer', 'kunden', 'preise',
                      'sparen', 'kosten', 'strom', 'habeck', 'inflation', 'ewe'],
    
    'covid' : ['corona', 'inzidenz', 'corona-inzidenz', 'neuinfektionen', 'infektionen',
               'infizierten', 'fälle', 'geimpft', 'corona-regeln', 'impfpflicht', 'maskenpflicht',
               'omikron', 'kliniken', 'klinikum', 'lauterbach', 'corona-impfung', 'quarantäne'],
    
    'unglückBrände' : ['feuerwehr', 'brand', 'feuer', 'einsatz', 'tote', 'feuerwehren', 'flammen',
                       'brennt', 'tot', 'schaden'],
    
    'öpnvVerkehr' : ['gesperrt', 'bahn', '9-euro-ticket', 'fahren', 'verkehr', 'bahnhof', 'straßen',
                     'bauarbeiten'],
    
    'kinderbetreuung' : ['kinder', 'schulen', 'schüler', 'schule', 'eltern', 'jugendliche',
                         'grundschule', 'kita', 'kitas', 'kindern'],
    
    'politik' : ['spd', 'landtagswahl', 'cdu', 'grüne', 'scholz', 'landtag', 'schröder', 'fdp',
                 'grünen', 'bund', 'afd', 'ministerpräsident', 'althusmann', 'wahl'],
    
    'kunstKulturFreizeit' : ['feiert', 'besucher', 'feiern', 'programm', 'schützenfest',
                             'theater', 'gefeiert', 'bildergalerie', 'konzert'],
    
    'wetterKlima' : ['wasser', 'sommer', 'wetter', 'sturm', 'hitze', 'regen', 'klimawandel'],
    
    'unglückUnfall' : ['unfall', 'verletzt', 'verletzte', 'stirbt', 'krankenhaus', 'verkehrsunfall'],
    
    'ukraine' : ['ukraine', 'krieg', 'russland', 'ukraine-krieg', 'flüchtlinge', 'geflüchtete', 'putin',
                 'ukrainische', 'russische', 'ukrainer'],
    
    'lokalesBsWob' : ['wolfsburg', 'braunschweig', 'wolfsburger', 'braunschweiger', 'volkswagen',
                      'braunschweigs', 'wolfsburgs', 'salzgitter'],
    
    'lokalesOstfriesland' : ['aurich', 'emden', 'auricher', 'emder', 'leeraner'],
    
    'justiz' : ['gericht', 'täter', 'fall', 'ermittelt', 'zeugen', 'prozess', 'verurteilt',
                'landgericht', 'haft', 'opfer', 'ermittlungen', 'staatsanwaltschaft', 'getötet',
                'urteil', 'festgenommen']
}

# %%
pp.pprint(categoriesNiedersachsen)
# Out:
# {'covid': ['corona',
#            'inzidenz',
#            'corona-inzidenz',
#            'neuinfektionen',
#            'infektionen',
#            'infizierten',
#            'fälle',
#            'geimpft',
#            'corona-regeln',
#            'impfpflicht',
#            'maskenpflicht',
#            'omikron',
#            'kliniken',
#            'klinikum',
#            'lauterbach',
#            'corona-impfung',
#            'quarantäne'],
#  'energiekrise': ['gas',
#                   'energiekrise',
#                   'energie',
#                   'teurer',
#                   'kunden',
#                   'preise',
#                   'sparen',
#                   'kosten',
#                   'strom',
#                   'habeck',
#                   'inflation',
#                   'ewe'],
#  'justiz': ['gericht',
#             'täter',
#             'fall',
#             'ermittelt',
#             'zeugen',
#             'prozess',
#             'verurteilt',
#             'landgericht',
#             'haft',
#             'opfer',
#             'ermittlungen',
#             'staatsanwaltschaft',
#             'getötet',
#             'urteil',
#             'festgenommen'],
#  'kinderbetreuung': ['kinder',
#                      'schulen',
#                      'schüler',
#                      'schule',
#                      'eltern',
#                      'jugendliche',
#                      'grundschule',
#                      'kita',
#                      'kitas',
#                      'kindern'],
#  'kunstKulturFreizeit': ['feiert',
#                          'besucher',
#                          'feiern',
#                          'programm',
#                          'schützenfest',
#                          'theater',
#                          'gefeiert',
#                          'bildergalerie',
#                          'konzert'],
#  'lokalesBsWob': ['wolfsburg',
#                   'braunschweig',
#                   'wolfsburger',
#                   'braunschweiger',
#                   'volkswagen',
#                   'braunschweigs',
#                   'wolfsburgs',
#                   'salzgitter'],
#  'lokalesOstfriesland': ['aurich', 'emden', 'auricher', 'emder', 'leeraner'],
#  'politik': ['spd',
#              'landtagswahl',
#              'cdu',
#              'grüne',
#              'scholz',
#              'landtag',
#              'schröder',
#              'fdp',
#              'grünen',
#              'bund',
#              'afd',
#              'ministerpräsident',
#              'althusmann',
#              'wahl'],
#  'ukraine': ['ukraine',
#              'krieg',
#              'russland',
#              'ukraine-krieg',
#              'flüchtlinge',
#              'geflüchtete',
#              'putin',
#              'ukrainische',
#              'russische',
#              'ukrainer'],
#  'unglückBrände': ['feuerwehr',
#                    'brand',
#                    'feuer',
#                    'einsatz',
#                    'tote',
#                    'feuerwehren',
#                    'flammen',
#                    'brennt',
#                    'tot',
#                    'schaden'],
#  'unglückUnfall': ['unfall',
#                    'verletzt',
#                    'verletzte',
#                    'stirbt',
#                    'krankenhaus',
#                    'verkehrsunfall'],
#  'wetterKlima': ['wasser',
#                  'sommer',
#                  'wetter',
#                  'sturm',
#                  'hitze',
#                  'regen',
#                  'klimawandel'],
#  'öpnvVerkehr': ['gesperrt',
#                  'bahn',
#                  '9-euro-ticket',
#                  'fahren',
#                  'verkehr',
#                  'bahnhof',
#                  'straßen',
#                  'bauarbeiten']}

# %%
dfsNiedersachsen = []

for key,values in categoriesNiedersachsen.items():
    words=pd.DataFrame({'category': key, 'term': values})
    dfsNiedersachsen.append(words)

termsNiedersachsen = pd.concat(dfsNiedersachsen)
termsNiedersachsen
# Out:
#         category                term
# 0   energiekrise                 gas
# 1   energiekrise        energiekrise
# 2   energiekrise             energie
# 3   energiekrise              teurer
# 4   energiekrise              kunden
# ..           ...                 ...
# 10        justiz        ermittlungen
# 11        justiz  staatsanwaltschaft
# 12        justiz             getötet
# 13        justiz              urteil
# 14        justiz        festgenommen
#
# [131 rows x 2 columns]

# %%
# Take the 'term' column from our list of terms
termlistNiedersachsen = list(set(termsNiedersachsen.term))

# binary=True only does 0/1
# vocabulary= is the list of words we're interested in tracking
vectorizer = TfidfVectorizer(binary=False, vocabulary = termlistNiedersachsen)

matrix = vectorizer.fit_transform(niedersachsen.text, )

words_df = pd.DataFrame(matrix.toarray(), columns = vectorizer.get_feature_names_out())

# %%
# Group the terms by category, then loop through each category
for category_name, rows in termsNiedersachsen.groupby('category'):
    # Convert the terms for that category into a simple list
    # for example, ['student', 'educ', 'teacher']
    terms = list(rows['term'])
    print(f"Topic: {category_name} \nWorte: {terms} \n")

    # words_df[terms] gets the columns for 'student', 'educ', and 'teacher'
    # .any(axis=1) sees if any of them are a 1, gives True/False
    # .astype(int) converts True/False to 1/0
    # df[category_name] = will assign that value to df['education']
    niedersachsen[category_name] = words_df[terms].any(axis=1).astype(int)
# Out:
# Topic: covid
# Worte: ['corona', 'inzidenz', 'corona-inzidenz', 'neuinfektionen', 'infektionen', 'infizierten', 'fälle', 'geimpft', 'corona-regeln', 'impfpflicht', 'maskenpflicht', 'omikron', 'kliniken', 'klinikum', 'lauterbach', 'corona-impfung', 'quarantäne']
#
# Topic: energiekrise
# Worte: ['gas', 'energiekrise', 'energie', 'teurer', 'kunden', 'preise', 'sparen', 'kosten', 'strom', 'habeck', 'inflation', 'ewe']
#
# Topic: justiz
# Worte: ['gericht', 'täter', 'fall', 'ermittelt', 'zeugen', 'prozess', 'verurteilt', 'landgericht', 'haft', 'opfer', 'ermittlungen', 'staatsanwaltschaft', 'getötet', 'urteil', 'festgenommen']
#
# Topic: kinderbetreuung
# Worte: ['kinder', 'schulen', 'schüler', 'schule', 'eltern', 'jugendliche', 'grundschule', 'kita', 'kitas', 'kindern']
#
# Topic: kunstKulturFreizeit
# Worte: ['feiert', 'besucher', 'feiern', 'programm', 'schützenfest', 'theater', 'gefeiert', 'bildergalerie', 'konzert']
#
# Topic: lokalesBsWob
# Worte: ['wolfsburg', 'braunschweig', 'wolfsburger', 'braunschweiger', 'volkswagen', 'braunschweigs', 'wolfsburgs', 'salzgitter']
#
# Topic: lokalesOstfriesland
# Worte: ['aurich', 'emden', 'auricher', 'emder', 'leeraner']
#
# Topic: politik
# Worte: ['spd', 'landtagswahl', 'cdu', 'grüne', 'scholz', 'landtag', 'schröder', 'fdp', 'grünen', 'bund', 'afd', 'ministerpräsident', 'althusmann', 'wahl']
#
# Topic: ukraine
# Worte: ['ukraine', 'krieg', 'russland', 'ukraine-krieg', 'flüchtlinge', 'geflüchtete', 'putin', 'ukrainische', 'russische', 'ukrainer']
#
# Topic: unglückBrände
# Worte: ['feuerwehr', 'brand', 'feuer', 'einsatz', 'tote', 'feuerwehren', 'flammen', 'brennt', 'tot', 'schaden']
#
# Topic: unglückUnfall
# Worte: ['unfall', 'verletzt', 'verletzte', 'stirbt', 'krankenhaus', 'verkehrsunfall']
#
# Topic: wetterKlima
# Worte: ['wasser', 'sommer', 'wetter', 'sturm', 'hitze', 'regen', 'klimawandel']
#
# Topic: öpnvVerkehr
# Worte: ['gesperrt', 'bahn', '9-euro-ticket', 'fahren', 'verkehr', 'bahnhof', 'straßen', 'bauarbeiten']

# %%
niedersachsen.groupby('user').politik.sum().sort_values(ascending=False)
# Out:
# user
# SZLZ1              2039
# HAZ                 596
# goetageblatt        521
# neuepresse          487
# Dewezet             421
# Rundblick_NDS       387
# noz_de              272
# oz_online_de        243
# sn_online           228
# lzgezwitscher       217
# ga_online           202
# BS_Zeitung          199
# wazwolfsburg        198
# nwzonline           164
# pazpeine            160
# on_online_de        151
# azgifhorn           150
# Kreisblatt           91
# Kreiszeitung         85
# TAGEBLATTonline      62
# cezett               51
# Die_Harke            40
# HarzKurier           35
# einmorgenpost         8
# Harlinger1862         5
# goslarsche            4
# hinews                1
# kzw_redaktion         0
# WZonline              0
# Wochenblatt1791       0
# Name: politik, dtype: int64

# %%
niedersachsen.groupby('user').sum()
# Out:
#                                                           dateTime  \
# user
# BS_Zeitung       2022-10-31T22:46:06Z2022-10-31T22:15:24Z2022-1...
# Dewezet          2022-10-31T21:46:42Z2022-10-31T21:03:56Z2022-1...
# Die_Harke        2022-10-31T17:56:59Z2022-10-31T16:52:46Z2022-1...
# HAZ              2022-10-31T18:32:12Z2022-10-31T17:49:27Z2022-1...
# Harlinger1862    2022-10-26T09:50:14Z2022-10-17T08:29:49Z2022-1...
# HarzKurier       2022-10-27T09:57:01Z2022-10-27T06:11:53Z2022-1...
# Kreisblatt       2022-10-31T15:02:03Z2022-10-31T13:17:35Z2022-1...
# Kreiszeitung     2022-10-28T14:01:46Z2022-10-28T12:27:46Z2022-1...
# Rundblick_NDS    2022-10-31T15:34:50Z2022-10-31T10:05:09Z2022-1...
# SZLZ1            2022-10-17T08:57:01Z2022-10-13T18:02:06Z2022-1...
# TAGEBLATTonline  2022-10-31T19:51:02Z2022-10-31T16:34:45Z2022-1...
# WZonline         2022-05-05T08:07:22Z2022-02-01T10:41:32Z2022-0...
# Wochenblatt1791  2022-05-05T08:07:03Z2022-02-01T10:41:32Z2022-0...
# azgifhorn        2022-10-31T18:08:18Z2022-10-31T10:14:48Z2022-1...
# cezett           2022-10-28T05:59:16Z2022-10-28T05:51:44Z2022-1...
# einmorgenpost    2022-10-31T18:33:03Z2022-10-31T18:25:07Z2022-1...
# ga_online        2022-10-31T16:09:52Z2022-10-31T14:38:22Z2022-1...
# goetageblatt     2022-10-31T20:50:37Z2022-10-31T20:15:49Z2022-1...
# goslarsche       2022-09-04T11:48:05Z2022-05-12T11:13:00Z2022-0...
# hinews           2022-10-09T18:00:39Z2022-03-25T17:50:22Z2022-0...
# kzw_redaktion             2022-09-11T14:29:56Z2022-09-08T13:18:57Z
# lzgezwitscher    2022-10-31T18:40:54Z2022-10-31T15:19:00Z2022-1...
# neuepresse       2022-10-31T20:50:36Z2022-10-31T20:21:14Z2022-1...
# noz_de           2022-10-31T20:53:33Z2022-10-31T20:07:02Z2022-1...
# nwzonline        2022-10-31T21:54:52Z2022-10-31T21:05:03Z2022-1...
# on_online_de     2022-10-31T19:55:43Z2022-10-31T18:42:11Z2022-1...
# oz_online_de     2022-10-31T17:55:52Z2022-10-31T17:30:37Z2022-1...
# pazpeine         2022-10-31T17:54:47Z2022-10-31T11:52:12Z2022-1...
# sn_online        2022-10-31T20:42:24Z2022-10-31T20:15:54Z2022-1...
# wazwolfsburg     2022-10-31T14:31:56Z2022-10-31T13:59:54Z2022-1...
#
#                       tweetID  \
# user
# BS_Zeitung       9.955791e+21
# Dewezet          1.517659e+22
# Die_Harke        5.264101e+21
# HAZ              9.294628e+21
# Harlinger1862    1.507403e+20
# HarzKurier       2.601286e+21
# Kreisblatt       6.723040e+21
# Kreiszeitung     1.623584e+21
# Rundblick_NDS    1.555904e+21
# SZLZ1            5.170944e+22
# TAGEBLATTonline  4.249083e+21
# WZonline         1.634252e+19
# Wochenblatt1791  2.077685e+19
# azgifhorn        6.066522e+21
# cezett           1.340295e+21
# einmorgenpost    1.361318e+21
# ga_online        9.033288e+21
# goetageblatt     2.018188e+22
# goslarsche       1.171991e+20
# hinews           7.606575e+18
# kzw_redaktion    3.136835e+18
# lzgezwitscher    4.210480e+21
# neuepresse       1.500028e+22
# noz_de           4.788057e+21
# nwzonline        6.204126e+21
# on_online_de     6.024549e+21
# oz_online_de     1.279751e+22
# pazpeine         8.084811e+21
# sn_online        4.767048e+21
# wazwolfsburg     1.034678e+22
#
#                                                            content  replies  \
# user
# BS_Zeitung       So begehen Braunschweiger Kirchen das Fest der...      389
# Dewezet          Bei Galeria Karstadt Kaufhof droht über 40 Fil...       84
# Die_Harke        Darüber spricht Nienburg am Abend https://t.co...       49
# HAZ              Die Polizei versucht mit einer Öffentlichkeits...    10605
# Harlinger1862    Wie geht es beim insolventen Golfclub Ostfries...        3
# HarzKurier       Restaurant Da Capo in Osterode soll mit neuem ...       46
# Kreisblatt       Nach zweijähriger Pause: Nikolausfahrten mit „...       40
# Kreiszeitung     „Raving Rishi“: Party-Video aus Ibiza sorgt fü...      250
# Rundblick_NDS    EIL: Entgegen der ursprünglichen Planung werde...      266
# SZLZ1            Aktuelle Einsätze in Schaumburg: Erneuter Raub...      101
# TAGEBLATTonline  Reformationstag oder Halloween: So hat der Lan...      265
# WZonline         Die Bauarbeiten sind eröffnet! Unter den Augen...        2
# Wochenblatt1791  Die Bauarbeiten sind eröffnet! Unter den Augen...        2
# azgifhorn        Wenn am Dienstag der Kanzler kommt: Parkverbot...       47
# cezett           Einem Oldauer (31) wird vorgeworfen, einen Unf...       67
# einmorgenpost    Pointenreich und originell https://t.co/61MYU4...       14
# ga_online        Für die Landräte in Leer und Aurich ist ein Gr...       56
# goetageblatt     TSV Landolfshausen/Seulingen beherrscht im Der...      360
# goslarsche       #Großbrand am #Brocken: Löschhubschrauber hole...        8
# hinews           @SchwebelR Das hier ist unser Ticker zur Landt...        4
# kzw_redaktion    Tolle Technik aus #Nordenham #Wesermarsch von ...        1
# lzgezwitscher    Im Bülows Kamp wird’s gruselig!  Zum 31. Oktob...      523
# neuepresse       Rettungsschirm, mehr Geld für Lehrer, Agrarwen...     2648
# noz_de           US-Politikerin Pelosi sollte entführt werden -...      736
# nwzonline        Die sehr destruktiv ausgerichtete Taktik von T...      489
# on_online_de     Auf mehr als 100 Meter wird sich die Anlage am...       44
# oz_online_de     Nach dem Dämpfer gegen Lohne geht es für Kicke...      321
# pazpeine         Kreis Peine: Hier wird am Dienstag geblitzt ht...       52
# sn_online        Landesligist VfR Evesen marschiert Richtung Ob...      117
# wazwolfsburg     Wolfsburgs Fußballerinnen nach dem Sieg in Bre...      235
#
#                  retweets  likes  quotes  \
# user
# BS_Zeitung            307   1722     145
# Dewezet               108    580      36
# Die_Harke              64    404       9
# HAZ                  4599  32226    1958
# Harlinger1862          16     45       1
# HarzKurier            317    450      14
# Kreisblatt             19    217      48
# Kreiszeitung          141    460      50
# Rundblick_NDS         587   1676     205
# SZLZ1                  88    899      46
# TAGEBLATTonline      1633   2323      58
# WZonline                3     22       0
# Wochenblatt1791        11     14       0
# azgifhorn              32    220      26
# cezett                146    471      25
# einmorgenpost          98    647       5
# ga_online              50    349      10
# goetageblatt         1720   3117     257
# goslarsche             31    134       3
# hinews                  1      1       0
# kzw_redaktion           0      0       0
# lzgezwitscher         629   3016     128
# neuepresse           1514  17236     535
# noz_de                769   2308     203
# nwzonline             744   3444     141
# on_online_de           76    886       7
# oz_online_de         3219   5253     146
# pazpeine               27    234      10
# sn_online             125    632      26
# wazwolfsburg          284   2139     139
#
#                                                              media  \
# user
# BS_Zeitung       [Photo(previewUrl='https://pbs.twimg.com/media...
# Dewezet          [Photo(previewUrl='https://pbs.twimg.com/media...
# Die_Harke                                                        0
# HAZ              [Photo(previewUrl='https://pbs.twimg.com/media...
# Harlinger1862    [Photo(previewUrl='https://pbs.twimg.com/media...
# HarzKurier       [Photo(previewUrl='https://pbs.twimg.com/media...
# Kreisblatt                                                       0
# Kreiszeitung                                                     0
# Rundblick_NDS    [Photo(previewUrl='https://pbs.twimg.com/media...
# SZLZ1            [Photo(previewUrl='https://pbs.twimg.com/media...
# TAGEBLATTonline  [Photo(previewUrl='https://pbs.twimg.com/media...
# WZonline         [Photo(previewUrl='https://pbs.twimg.com/media...
# Wochenblatt1791  [Photo(previewUrl='https://pbs.twimg.com/media...
# azgifhorn        [Photo(previewUrl='https://pbs.twimg.com/media...
# cezett           [Photo(previewUrl='https://pbs.twimg.com/media...
# einmorgenpost    [Photo(previewUrl='https://pbs.twimg.com/media...
# ga_online        [Photo(previewUrl='https://pbs.twimg.com/media...
# goetageblatt     [Photo(previewUrl='https://pbs.twimg.com/media...
# goslarsche       [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# hinews                                                           0
# kzw_redaktion                                                    0
# lzgezwitscher    [Photo(previewUrl='https://pbs.twimg.com/media...
# neuepresse       [Photo(previewUrl='https://pbs.twimg.com/media...
# noz_de           [Photo(previewUrl='https://pbs.twimg.com/media...
# nwzonline        [Photo(previewUrl='https://pbs.twimg.com/media...
# on_online_de     [Photo(previewUrl='https://pbs.twimg.com/media...
# oz_online_de     [Photo(previewUrl='https://pbs.twimg.com/media...
# pazpeine         [Photo(previewUrl='https://pbs.twimg.com/media...
# sn_online        [Photo(previewUrl='https://pbs.twimg.com/media...
# wazwolfsburg     [Photo(previewUrl='https://pbs.twimg.com/media...
#
#                  isRetweeted  isQuoted  ...  kinderbetreuung  \
# user                                    ...
# BS_Zeitung               0.0       0.0  ...              211
# Dewezet                  0.0       0.0  ...              263
# Die_Harke                0.0       0.0  ...              142
# HAZ                      0.0       0.0  ...              372
# Harlinger1862            0.0       0.0  ...                5
# HarzKurier               0.0       0.0  ...               58
# Kreisblatt               0.0       0.0  ...              158
# Kreiszeitung             0.0       0.0  ...               21
# Rundblick_NDS            0.0       0.0  ...               29
# SZLZ1                    0.0       0.0  ...              919
# TAGEBLATTonline          0.0       0.0  ...              115
# WZonline                 0.0       0.0  ...                2
# Wochenblatt1791          0.0       0.0  ...                2
# azgifhorn                0.0       0.0  ...              198
# cezett                   0.0       0.0  ...               44
# einmorgenpost            0.0       0.0  ...               31
# ga_online                0.0       0.0  ...              251
# goetageblatt             0.0       0.0  ...              572
# goslarsche               0.0       0.0  ...                3
# hinews                   0.0       0.0  ...                0
# kzw_redaktion            0.0       0.0  ...                0
# lzgezwitscher            0.0       0.0  ...              200
# neuepresse               0.0       0.0  ...              452
# noz_de                   0.0       0.0  ...               70
# nwzonline                0.0       0.0  ...              166
# on_online_de             0.0       0.0  ...              226
# oz_online_de             0.0       0.0  ...              320
# pazpeine                 0.0       0.0  ...              206
# sn_online                0.0       0.0  ...              231
# wazwolfsburg             0.0       0.0  ...              212
#
#                 kunstKulturFreizeit lokalesBsWob  lokalesOstfriesland  \
# user
# BS_Zeitung                       84         3032                    9
# Dewezet                         239           45                    1
# Die_Harke                        75            3                    0
# HAZ                             168           99                    5
# Harlinger1862                     7            0                    2
# HarzKurier                       58            9                    1
# Kreisblatt                       86            1                    3
# Kreiszeitung                      8            0                    0
# Rundblick_NDS                    12            4                    3
# SZLZ1                           604          546                   52
# TAGEBLATTonline                  55            0                    1
# WZonline                          1            0                    0
# Wochenblatt1791                   0            0                    0
# azgifhorn                        85           69                    1
# cezett                           11            2                    0
# einmorgenpost                    20            0                    0
# ga_online                       175           17                  628
# goetageblatt                    448           97                    4
# goslarsche                        7            2                    0
# hinews                            0            0                    0
# kzw_redaktion                     0            0                    0
# lzgezwitscher                    90            1                    1
# neuepresse                      234           94                    9
# noz_de                           20            2                    1
# nwzonline                        87           14                  289
# on_online_de                     90            5                 1369
# oz_online_de                    192           21                 2191
# pazpeine                        162          142                    7
# sn_online                       130           11                    0
# wazwolfsburg                    285         3707                   11
#
#                  politik ukraine  unglückBrände  unglückUnfall wetterKlima  \
# user
# BS_Zeitung           199     240            159            244          85
# Dewezet              421     641            306            139          96
# Die_Harke             40      56            125             80          25
# HAZ                  596     452            218            233         160
# Harlinger1862          5       4              9              7           2
# HarzKurier            35      31            117             84          29
# Kreisblatt            91     102            131            207          29
# Kreiszeitung          85     120             37             36          15
# Rundblick_NDS        387     122              9              1           6
# SZLZ1               2039    1355           1404           1079         476
# TAGEBLATTonline       62      60            140            115          35
# WZonline               0       1              0              1           0
# Wochenblatt1791        0       1              0              1           1
# azgifhorn            150     157            105             89          68
# cezett                51      56             54             57          15
# einmorgenpost          8      16             24             12           5
# ga_online            202     218            275            226         136
# goetageblatt         521     354            420            401         147
# goslarsche             4       2              5              2           2
# hinews                 1       0              0              0           0
# kzw_redaktion          0       0              0              0           0
# lzgezwitscher        217     180            129             47          85
# neuepresse           487     322            253            283         141
# noz_de               272     190             78             60          26
# nwzonline            164     195            266            215          81
# on_online_de         151     208            250            169          63
# oz_online_de         243     265            413            340         204
# pazpeine             160     169            157            158          62
# sn_online            228     167            207            101          76
# wazwolfsburg         198     235            165            136          81
#
#                  öpnvVerkehr
# user
# BS_Zeitung               113
# Dewezet                  131
# Die_Harke                 41
# HAZ                      245
# Harlinger1862              0
# HarzKurier                58
# Kreisblatt                59
# Kreiszeitung              11
# Rundblick_NDS              7
# SZLZ1                    464
# TAGEBLATTonline          102
# WZonline                   1
# Wochenblatt1791            1
# azgifhorn                 79
# cezett                    20
# einmorgenpost             11
# ga_online                180
# goetageblatt             280
# goslarsche                 4
# hinews                     0
# kzw_redaktion              0
# lzgezwitscher            142
# neuepresse               203
# noz_de                    22
# nwzonline                154
# on_online_de             102
# oz_online_de             249
# pazpeine                  82
# sn_online                107
# wazwolfsburg             102
#
# [30 rows x 40 columns]

# %%
niedersachsenCategorized = niedersachsen
niedersachsenCategorized.to_csv("../../methods/representative-speech/mediendaten/zuordnungenBundesländer/niedersachsenCategorized.csv")
